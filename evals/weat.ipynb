# %%
from datasets import load_dataset

words = load_dataset("fairnlp/weat", data_files=["words.parquet"], split="train")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 from datasets import load_dataset
# ----> 3 words = load_dataset("fairnlp/weat", data_files=["words.parquet"], split="train")
#
# File /opt/anaconda3/lib/python3.11/site-packages/datasets/load.py:2132, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2127 verification_mode = VerificationMode(
#    2128     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2129 )
#    2131 # Create a dataset builder
# -> 2132 builder_instance = load_dataset_builder(
#    2133     path=path,
#    2134     name=name,
#    2135     data_dir=data_dir,
# ...

# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/fairnlp/weat/words.parquet")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_parquet("hf://datasets/fairnlp/weat/words.parquet")
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...

# %%
import pandas as pd

df = pd.read_parquet("hf://datasets/fairnlp/weat/associations_weat.parquet")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_parquet("hf://datasets/fairnlp/weat/associations_weat.parquet")
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# ...

# %%
import polars as pl

df = pl.read_parquet('hf://datasets/fairnlp/weat/words.parquet')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import polars as pl
#       3 df = pl.read_parquet('hf://datasets/fairnlp/weat/words.parquet')
#
# ModuleNotFoundError: No module named 'polars'

# %%
from responsibly.we.weat import calc_single_weat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from responsibly.we.weat import calc_single_weat
#
# ModuleNotFoundError: No module named 'responsibly'
